# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Transform the data in the txt file into a dataframe

# %%
# Read the file into a list of lines
with open('wiki-RfA.txt', 'r') as file:
    lines = file.readlines()

# Create a list of dictionaries, where each dictionary represents a record
all_pairs = []
current_entry = {}

# Iterate through each line, current_entry = one log entry with all columns, all_pairs = list of all votee/voter pairs
for line in lines:
    line = line.strip()
    if line:
        key, value = line.split(':', 1)
        current_entry[key] = value
    else:
        all_pairs.append(current_entry)
        current_entry = {}

# Append  last record
if current_entry:
    all_pairs.append(current_entry)

# Convert into DataFrame and store in csv
all_pairs = pd.DataFrame(all_pairs)
all_pairs.columns = ['Source', 'Target', 'Vote', 'Results', 'Year', 'Date', 'Comment']

all_pairs.to_csv('wiki-RfA.csv')
all_pairs
# Out:
#             Source        Target Vote Results  Year                  Date  \
# 0        Steel1943           BDD    1       1  2013  23:13, 19 April 2013
# 1       Cuchullain           BDD    1       1  2013  01:04, 20 April 2013
# 2        INeverCry           BDD    1       1  2013  23:43, 19 April 2013
# 3        Cncmaster           BDD    1       1  2013  00:11, 20 April 2013
# 4       Miniapolis           BDD    1       1  2013  00:56, 20 April 2013
# ...            ...           ...  ...     ...   ...                   ...
# 198270         172  Vancouverguy    1       1  2003     02:51, 2 Sep 2003
# 198271      Angela   WhisperToMe    1       1  2003    23:45, 26 Nov 2003
# 198272       Jiang   WhisperToMe    1       1  2003
# 198273     Pakaran   WhisperToMe    1       1  2003     05:38, 5 Dec 2003
# 198274    Jimregan       Zanimum    1       1  2003
#
#                                                   Comment
# 0                                '''Support''' as co-nom.
# ...

# %% [markdown]
# # Handle inconsistent data

# %% [markdown]
# date = all_pairs['Date'].str.split(',', expand=True, n=1)
# date2 = date[1].str.strip()
# date2 = date2.str.split(' ', expand=True, n=2)
# \# concatenate the two dataframes
# date3 = pd.concat([date[0], date2], axis=1)
# date3.columns = ['Hour', 'Day', 'Month', 'Year']
# date4 = date3['Hour'].str.split(':', expand=True, n=1)
# date4.columns = ['Hour', 'Minute']
# date3['Month'].unique()

# %%
# Set Nan values
# replace field that's entirely space (or empty) with NaN
all_pairs.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# replace inconsistent date
all_pairs['Date'] = all_pairs['Date'].str.replace('Julu ', 'July ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Janry ', 'January ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Mya ', 'May ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Jan ', 'January ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Feb ', 'February ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Mar ', 'March ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Apr ', 'April ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Jun ', 'June ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Jul ', 'July ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Aug ', 'August ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Sep ', 'September ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Oct ', 'October ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Nov ', 'November ')
all_pairs['Date'] = all_pairs['Date'].str.replace('Dec ', 'December ')



# Convert Date to datetime
all_pairs['Date'] = pd.to_datetime(all_pairs['Date'], format='%H:%M, %d %B %Y', errors='coerce')

all_pairs
# Out:
#             Source        Target Vote Results  Year                Date  \
# 0        Steel1943           BDD    1       1  2013 2013-04-19 23:13:00
# 1       Cuchullain           BDD    1       1  2013 2013-04-20 01:04:00
# 2        INeverCry           BDD    1       1  2013 2013-04-19 23:43:00
# 3        Cncmaster           BDD    1       1  2013 2013-04-20 00:11:00
# 4       Miniapolis           BDD    1       1  2013 2013-04-20 00:56:00
# ...            ...           ...  ...     ...   ...                 ...
# 198270         172  Vancouverguy    1       1  2003 2003-09-02 02:51:00
# 198271      Angela   WhisperToMe    1       1  2003 2003-11-26 23:45:00
# 198272       Jiang   WhisperToMe    1       1  2003                 NaT
# 198273     Pakaran   WhisperToMe    1       1  2003 2003-12-05 05:38:00
# 198274    Jimregan       Zanimum    1       1  2003                 NaT
#
#                                                   Comment
# ...

# %% [markdown]
# # Some statistics and visualisation

# %%
stats = all_pairs.describe(include='all')
stats.loc['perc_nan'] = (1 - stats.loc['count'] / len(all_pairs)) * 100
stats
# Out:
#             Source     Target    Vote Results    Year  \
# count       196614     198275  198275  198275  198275
# unique       10416       3497       3       2      11
# top       Siva1979  Everyking       1       1    2006
# freq          1232        987  144451  123288   45325
# mean           NaN        NaN     NaN     NaN     NaN
# min            NaN        NaN     NaN     NaN     NaN
# 25%            NaN        NaN     NaN     NaN     NaN
# 50%            NaN        NaN     NaN     NaN     NaN
# 75%            NaN        NaN     NaN     NaN     NaN
# max            NaN        NaN     NaN     NaN     NaN
# perc_nan  0.837725        0.0     0.0     0.0     0.0
#
#                                    Date        Comment
# count                            188907         191085
# unique                              NaN         163218
# top                                 NaN  '''Support'''
# freq                                NaN           3456
# ...

# %%
categorical_cols = ['Source', 'Target']
value_cols = ['Vote', 'Results', 'Year']
all_cols = categorical_cols + value_cols
n_top = 20
fig, axes = plt.subplots(len(all_cols), 2, figsize=(10,4*len(all_cols)))
for i, col in enumerate(all_cols):
    ax1 = axes[(2*i) // 2, (2*i) % 2]
    ax2 = axes[(2*i+1) // 2, (2*i+1) % 2]
    data = all_pairs[~all_pairs[col].isna()]
    if col in categorical_cols:
        top_n = pd.Series(data[col].value_counts().iloc[:n_top])
        others = pd.Series(data[col].value_counts().iloc[n_top:].sum(), index=['Others'])
        value_counts = pd.concat([top_n, others])
        
    elif col in value_cols:
        value_counts = data[col].value_counts()
        
    # Count plot
    chart = sns.countplot(data=data, x=col, ax=ax1, order = value_counts.index)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=60, horizontalalignment='right', fontsize = 8)
    ax1.set_title('Histogram of the ' + col)
    
    # Pie chart
    val_counts = value_counts/np.sum(value_counts)
    labels = val_counts.index.to_list()

    wedges, texts, autotexts = ax2.pie(val_counts, labels = labels, autopct='%1.1f%%')
    threshold = 3
    for label, pct_label in zip(texts, autotexts):
        pct_value = pct_label.get_text().rstrip('%')
        if float(pct_value) < threshold:
            label.set_text('')
            pct_label.set_text('')
    
    ax2.legend(bbox_to_anchor=(1.05, 1), fontsize = 8)
    ax2.set_title('Pie chart of the ' + col)

fig.tight_layout()    
plt.show()
# Out:
# /Users/emmaboehly/programmation/anaconda3/envs/ADA/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/emmaboehly/programmation/anaconda3/envs/ADA/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/emmaboehly/programmation/anaconda3/envs/ADA/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
print(all_pairs['Comment'])
# Out:
# 0                                  '''Support''' as co-nom.
# 1                             '''Support''' as nominator.--
# 2                                   '''Support''' per noms.
# 3         '''Support''' per noms. BDD is a strong contri...
# 4         '''Support''', with great pleasure. I work wit...
#                                 ...
# 198270                                              Support
# 198271                                             Support.
# 198272                                          Support. --
# 198273    Support.  Age has nothing to do with maturity....
# 198274    Support - anyone who can write so much, and so...
# Name: Comment, Length: 198275, dtype: object

# %%
# plot Vote and Results columns against Date on the same plot with pandas

# %%
datetime = all_pairs.sort_values('Date', ascending=True)
datetime = datetime.groupby('Target').

'''plt.plot(datetime['Date'], datetime['Vote'])
plt.xticks(rotation='vertical')
plt.show()'''
datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/emmaboehly/Documents/Master3/ADA/WikiAdminship/P1_visualisation.ipynb Cellule 10 line 2
#       <a href='vscode-notebook-cell:/Users/emmaboehly/Documents/Master3/ADA/WikiAdminship/P1_visualisation.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> datetime = all_pairs.sort_values('Date', ascending=True)
# ----> <a href='vscode-notebook-cell:/Users/emmaboehly/Documents/Master3/ADA/WikiAdminship/P1_visualisation.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> datetime = datetime.groupby('Target').unique()
#       <a href='vscode-notebook-cell:/Users/emmaboehly/Documents/Master3/ADA/WikiAdminship/P1_visualisation.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> '''plt.plot(datetime['Date'], datetime['Vote'])
# ...
